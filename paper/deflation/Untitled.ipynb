# %%
import numpy as np
import matplotlib.pyplot as plt

x0 = np.zeros(1)
alpha = 1
r = 1
deflation = lambda x: (np.exp(-alpha/(r**2-np.linalg.norm(x-x0)**2) + alpha/r**2) if np.linalg.norm(x-x0)<r else 0)
x = np.arange(-1.5, 1.5, 1e-4)
y = np.array([deflation(z) for z in x])


fig, ax = plt.subplots(2, 1, figsize=(12,10))

plt.subplot(211)
plt.title('bump function (x0=0)')
plt.plot(x, y)

plt.subplot(212)
plt.title(r'$\frac{1}{1-bump}$')
plt.yscale('log')
plt.plot(x, 1./(1-y))

plt.savefig('bump.png')
# Out:
# /home/elliott/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: divide by zero encountered in true_divide
